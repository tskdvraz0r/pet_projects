# %%
from MathStat import Math

# %%
Math.Cube.value(5)
# Out:
# 125

# %%
Math.Cube.square(5)
# Out:
# 150

# %%
Math.Progression.arithmetic(5, 2, 50)
# Out:
# 103

# %%
Math.Progression.geometric(5, 2, 50)
# Out:
# 2814749767106560
